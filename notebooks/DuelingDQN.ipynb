# %% [markdown]
# # Importations

# %%
import numpy as np 
import matplotlib.pyplot as plt
import gym
# %matplotlib inline
import torch 
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import os 
import collections
# !pip install tensor-dash
from tensordash.tensordash import Tensordash
import torch.nn.functional as F


import sys
# Import python files 
# !wget https://github.com/clementbernardd/Count-Based-Exploration/raw/main/zip/python.zip
# !unzip python.zip
# !rm python.zip
# !mkdir models
# !mkdir results

sys.path.append('/content/python')

from RL_algorithm import *
from utils import * 
from buffer import * 
from simhash import * 
from train import * 
from dueling_dqn_agent import * 
from dueling_qnetwork import * 


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Collecting tensor-dash
#   Downloading https://files.pythonhosted.org/packages/d1/a7/d6714fea01209936e23bdd1db91c61c94a8f6ee718fede28afbff63241d4/tensor_dash-1.8.1-py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from tensor-dash) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->tensor-dash) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->tensor-dash) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->tensor-dash) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->tensor-dash) (2020.12.5)
# Installing collected packages: tensor-dash
# Successfully installed tensor-dash-1.8.1
# --2021-04-26 11:55:45--  https://github.com/clementbernardd/Count-Based-Exploration/raw/main/zip/python.zip
# Resolving github.com (github.com)... 52.192.72.89
# Connecting to github.com (github.com)|52.192.72.89|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/clementbernardd/Count-Based-Exploration/main/zip/python.zip [following]
# --2021-04-26 11:55:45--  https://raw.githubusercontent.com/clementbernardd/Count-Based-Exploration/main/zip/python.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16190 (16K) [application/zip]
# Saving to: ‘python.zip’
#
# python.zip          100%[===================>]  15.81K  --.-KB/s    in 0s
#
# 2021-04-26 11:55:45 (134 MB/s) - ‘python.zip’ saved [16190/16190]
#
# Archive:  python.zip
#    creating: python/
#    creating: python/__pycache__/
#   inflating: python/__pycache__/RL_algorithm.cpython-38.pyc
#   inflating: python/RL_algorithm.py
#   inflating: python/utils.py
#   inflating: python/q_learning.py
#   inflating: python/sarsa.py
#   inflating: python/qnetwork.py
#   inflating: python/buffer.py
#   inflating: python/dqn_agent.py
#   inflating: python/state.py
#   inflating: python/simhash.py
#   inflating: python/train.py
#   inflating: python/ddqn_agent.py
#   inflating: python/discretize.py
#   inflating: python/dueling_dqn_agent.py
#   inflating: python/dueling_qnetwork.py

# %% [markdown]
# # Environments

# %%
# Mountain Car 
# env = gym.make('MountainCar-v0')
# env = gym.make('CartPole-v0')
# Mountain Car Continuous
# env = gym.make('MountainCarContinuous-v0')
# CartPoleSwingUp
# env = gym.make("CartPoleSwingUp-v0")
# Acrobot
# env = gym.make('Acrobot-v1')
# Pendulum
# env = gym.make('Pendulum-v0')

# env = gym.make("Taxi-v3").env

# %%
ENVS = {'acrobot' : gym.make('Acrobot-v1') ,\
        'cartpole' : gym.make('CartPole-v0'),
        'mountain' : gym.make('MountainCar-v0')}

# %%
NAME_ALGORITHM = 'dueling_dqn'
SEEDS = [77,7,17,75,73,2,11,89,99,6]
# SEEDS = [77,7,17]

# %%
create_files(ENVS, NAME_ALGORITHM)

# %% [markdown]
# # Dueling DQN

# %% [markdown]
# ![picture](https://raw.githubusercontent.com/clementbernardd/Count-Based-Exploration/main/images/dueling_dqn.jpg)

# %% [markdown]
# # Count based exploration

# %% [markdown]
# ![picture](https://github.com/clementbernardd/Count-Based-Exploration/raw/main/images/algorithm1.png)

# %%
HP = {'acrobot' : {
            'BUFFER_SIZE' : 500,
            'state_emb' : 64,
            'hidden_size' : 64,
            'batch_size' : 64,
            'gamma' : 0.99,
            'optimizer' : optim.Adam,
            'criterion' : nn.MSELoss(),
            'lr' : 1e-3 ,
            'UPDATE_EVERY' : 10,
            'k' : 16,
            'beta' : 0.1,
            'device' : device
         },
      'cartpole' : 
      {
          'BUFFER_SIZE' : 5000,
            'state_emb' : 128,
            'hidden_size' : 64,
            'batch_size' : 64,
            'gamma' : 0.99,
            'optimizer' : optim.Adam,
            'criterion' : nn.MSELoss(),
            'lr' : 1e-3 ,
            'UPDATE_EVERY' : 10,
            'k' : 32,
            'beta' : 0.9,
            'device' : device
      },
      'mountain' : 
      {
            'BUFFER_SIZE' : 10000,
            'state_emb' : 64,
            'hidden_size' : 128,
            'batch_size' : 64,
            'gamma' : 0.99,
            'optimizer' : optim.Adam,
            'criterion' : nn.MSELoss(),
            'lr' : 1e-3 ,
            'UPDATE_EVERY' : 10,
            'k' : 64,
            'beta' : 0.9,
            'device' : device
      }
}

# %%
all_means = {env : None for env in ENVS}
all_means_cb = {env : None for env in ENVS}
all_hash_cb = {env : None for env in ENVS}

# %% [markdown]
# # Acrobot environment

# %%
CURRENT_ENV = list(ENVS.keys())[0]

# %%
all_means[CURRENT_ENV], _ = train_all_deep(DuelingDDQNAgent, HP[CURRENT_ENV], n_episodes = 200, name_env = CURRENT_ENV,env = ENVS[CURRENT_ENV],name = NAME_ALGORITHM,SEEDS = SEEDS,\
                                      TRAIN = Train, count_based= False)
# Out:
# SEED 0/10
# /content/python/buffer.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   experiences = np.array(list(self.buffer))[indexes]
# --- Save model checkpoint ---
# --- Save model checkpoint ---
# SEED 1/10
# SEED 2/10
# SEED 3/10
# SEED 4/10
# SEED 5/10
# SEED 6/10
# SEED 7/10
# SEED 8/10
# SEED 9/10

# %%
all_means_cb[CURRENT_ENV], all_hash_cb[CURRENT_ENV] = train_all_deep(DuelingDDQNAgent, HP[CURRENT_ENV], n_episodes = 200, name_env = CURRENT_ENV,\
                                                                env = ENVS[CURRENT_ENV],name = NAME_ALGORITHM,SEEDS = SEEDS,\
                                                                TRAIN = Train, count_based= True)
# Out:
# SEED 0/10
# /content/python/buffer.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   experiences = np.array(list(self.buffer))[indexes]
# --- Save model checkpoint ---
# --- Save model checkpoint ---
# SEED 1/10
# SEED 2/10
# SEED 3/10
# SEED 4/10
# SEED 5/10
# SEED 6/10
# SEED 7/10
# SEED 8/10
# SEED 9/10

# %% [markdown]
# ## Rewards

# %%
plot_rewards([all_means[CURRENT_ENV]], [all_means_cb[CURRENT_ENV]], names = [NAME_ALGORITHM], env_name = CURRENT_ENV)

# %% [markdown]
# ## Histogram of the states

# %%
hashes = get_hashes_mean(all_hash_cb[CURRENT_ENV])

# %%
plot_barchart_count_based(hashes, figsize = (18,8),method = NAME_ALGORITHM, env_name = CURRENT_ENV)

# %% [markdown]
# # Cartpole environment

# %%
CURRENT_ENV = list(ENVS.keys())[1]

# %%
all_means[CURRENT_ENV], _ = train_all_deep(DuelingDDQNAgent, HP[CURRENT_ENV], n_episodes = 200, name_env = CURRENT_ENV,env = ENVS[CURRENT_ENV],name = NAME_ALGORITHM,SEEDS = SEEDS,\
                                      TRAIN = Train, count_based= False)
# Out:
# SEED 0/10
# /content/python/buffer.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   experiences = np.array(list(self.buffer))[indexes]
# --- Save model checkpoint ---
# --- Save model checkpoint ---
# SEED 1/10
# SEED 2/10
# SEED 3/10
# SEED 4/10
# SEED 5/10
# SEED 6/10
# SEED 7/10
# SEED 8/10
# SEED 9/10

# %%
all_means_cb[CURRENT_ENV], all_hash_cb[CURRENT_ENV] = train_all_deep(DuelingDDQNAgent, HP[CURRENT_ENV], n_episodes = 200, name_env = CURRENT_ENV,\
                                                                env = ENVS[CURRENT_ENV],name = NAME_ALGORITHM,SEEDS = SEEDS,\
                                                                TRAIN = Train, count_based= True)
# Out:
# SEED 0/10
# /content/python/buffer.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   experiences = np.array(list(self.buffer))[indexes]
# --- Save model checkpoint ---
# --- Save model checkpoint ---
# SEED 1/10
# SEED 2/10
# SEED 3/10
# SEED 4/10
# SEED 5/10
# SEED 6/10
# SEED 7/10
# SEED 8/10
# SEED 9/10

# %% [markdown]
# ## Rewards

# %%
plot_rewards([all_means[CURRENT_ENV]], [all_means_cb[CURRENT_ENV]], names = [NAME_ALGORITHM], env_name = CURRENT_ENV)

# %% [markdown]
# ## Histogram of the states

# %%
hashes = get_hashes_mean(all_hash_cb[CURRENT_ENV])

# %%
plot_barchart_count_based(hashes, figsize = (18,8),method = NAME_ALGORITHM, env_name = CURRENT_ENV)

# %% [markdown]
# # Mountain car environment

# %%
CURRENT_ENV = list(ENVS.keys())[2]

# %%
all_means[CURRENT_ENV], _ = train_all_deep(DuelingDDQNAgent, HP[CURRENT_ENV], n_episodes = 500, name_env = CURRENT_ENV,env = ENVS[CURRENT_ENV],name = NAME_ALGORITHM,SEEDS = SEEDS,\
                                      TRAIN = Train, count_based = False)
# Out:
# SEED 0/10
# /content/python/buffer.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   experiences = np.array(list(self.buffer))[indexes]
# --- Save model checkpoint ---
# --- Save model checkpoint ---
# SEED 1/10
# SEED 2/10
# SEED 3/10
# SEED 4/10
# SEED 5/10
# SEED 6/10
# SEED 7/10
# SEED 8/10
# SEED 9/10

# %%
all_means_cb[CURRENT_ENV], all_hash_cb[CURRENT_ENV] = train_all_deep(DuelingDDQNAgent, HP[CURRENT_ENV], n_episodes = 500, name_env = CURRENT_ENV,\
                                                                env = ENVS[CURRENT_ENV],name = NAME_ALGORITHM,SEEDS = SEEDS,\
                                                                TRAIN = Train, count_based= True)
# Out:
# SEED 0/10
# /content/python/buffer.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   experiences = np.array(list(self.buffer))[indexes]
# --- Save model checkpoint ---
# --- Save model checkpoint ---
# SEED 1/10
# SEED 2/10
# SEED 3/10
# SEED 4/10
# SEED 5/10
# SEED 6/10
# SEED 7/10
# SEED 8/10
# SEED 9/10

# %% [markdown]
# ## Rewards

# %%
plot_rewards([all_means[CURRENT_ENV]], [all_means_cb[CURRENT_ENV]], names = [NAME_ALGORITHM], env_name = CURRENT_ENV)

# %% [markdown]
# ## Histogram of the states

# %%
hashes = get_hashes_mean(all_hash_cb[CURRENT_ENV])

# %%
plot_barchart_count_based(hashes, figsize = (18,8),method = NAME_ALGORITHM, env_name = CURRENT_ENV)
